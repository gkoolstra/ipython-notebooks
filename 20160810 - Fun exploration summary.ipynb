# %%
from matplotlib import pyplot as plt
import platform, os, sys
import numpy as np
from tabulate import tabulate
from pprint import pprint
from tqdm import tqdm

if 'Windows' in platform.system():
    print "Working in Windows..."
    sys.path.append(r'C:\Users\slab\Documents\Code')
    sys.path.append(r'D:\BEMPP_shared\Modules')
    import interpolate_slow
elif 'Linux' in platform.system():
    print "Working in Linux..."
    sys.path.append(r'/mnt/s/_Data/160603 - EonHe M016v5/modules')
    from BEM import interpolate_slow
    # %config InlineBackend.figure_format='retina'

from Common import common, kfit
from TrapAnalysis import trap_analysis, resonator_analysis, import_data
from HeliumSurface.static_surface import *

# %matplotlib inline
#%config InlineBackend.figure_format='retina'

common.configure_axes(13)
# Out:
# /home/ge/anaconda3/envs/lizards/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Working in Linux...

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %%
width = [5,5,
         5,5,
         7,7,
         4,4,
         3,3,
         2,2]
gap   = [5,5,
         7,7,
         5,5,
         3,3,
         2,2,
         1.5,1.5]
fe    = [9.6, 7.6, 
         9.0, 7.3, 
         6.7, 5.0, 
         14.2, 12.1, 
         20.0, 19.5, 
         26.5, 32.3]
height = [1.0, 0.5, 
          1.0, 0.5,
          1.0, 0.5,
          1.0, 0.5,
          1.0, 0.5,
          1.0, 0.5]
coupling = [17e3, 11e3, 
            17e3, 11e3, 
            9e3, 5e3,  
            47e3, 37e3, 
            92e3, 94e3, 
            150e3, 240e3]

# %%
plt.figure()
common.configure_axes(13)
plt.plot(width, fe, 'o', **common.plot_opt('r'))

ax, ax2 = common.setup_twinax(color1='r', color2='b')
ax.set_axis_bgcolor('none')
ax.set_xlabel("Width ($\mu$m)")
ax.set_ylabel('$f_e$ (GHz)')
ax.set_ylim(0, 35)
#ax.set_yscale('log')

ax2.plot(width, coupling, 'o', **common.plot_opt('b'))
ax2.set_ylabel('$E_x$ (V/m) at 1 $\mu$m from center')
ax2.set_yscale('log')

plt.title("Electron frequency and coupling \nvs. electrode width")
#common.save_figure(plt.gcf(), save_path=r'/mnt/s/Gerwin/Electron on helium/Maxwell/M017 Fun')

# %%
plt.figure()
common.configure_axes(13)
plt.plot(gap, fe, 'o', **common.plot_opt('r'))

ax, ax2 = common.setup_twinax(color1='r', color2='b')
ax.set_axis_bgcolor('none')
ax.set_xlabel("Gap ($\mu$m)")
ax.set_ylabel('$f_e$ (GHz)')
ax.set_ylim(0, 35)
#ax.set_yscale('log')

ax2.plot(gap, coupling, 'o', **common.plot_opt('b'))
ax2.set_ylabel('$E_x$ (V/m) at 1 $\mu$m from center')
ax2.set_yscale('log')

plt.title("Electron frequency and coupling \nvs. electrode gap")
#common.save_figure(plt.gcf(), save_path=r'/mnt/s/Gerwin/Electron on helium/Maxwell/M017 Fun')
